# %%
import dask.dataframe as dd
from dask.distributed import Client

client = Client(n_workers=6)
client
# Out:
# /home/arciel/.local/lib/python3.10/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 33467 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:40701' processes=6 threads=12, memory=7.55 GiB>

# %%
ddf = dd.read_parquet(
    "s3://dask-data/nyc-taxi/nyc-2015.parquet/part.*.parquet",
    columns=["passenger_count", "tip_amount"],
    storage_options={"anon": True},
)
# Out:
# 2023-06-12 11:05:27,785 - distributed.nanny - WARNING - Worker process still alive after 3.1999992370605472 seconds, killing
# 2023-06-12 11:05:27,786 - distributed.nanny - WARNING - Worker process still alive after 3.199999389648438 seconds, killing
# 2023-06-12 11:05:27,787 - distributed.nanny - WARNING - Worker process still alive after 3.199999389648438 seconds, killing
# 2023-06-12 11:05:27,788 - distributed.nanny - WARNING - Worker process still alive after 3.199999694824219 seconds, killing
# 2023-06-12 11:05:27,789 - distributed.nanny - WARNING - Worker process still alive after 3.1999995422363288 seconds, killing
# 2023-06-12 11:05:27,791 - distributed.nanny - WARNING - Worker process still alive after 3.199999694824219 seconds, killing
# 2023-06-12 11:05:27,795 - distributed.nanny - WARNING - Worker process still alive after 3.1999992370605472 seconds, killing

# %%
result = ddf.groupby("passenger_count").tip_amount.mean().compute()
result
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 result = ddf.groupby("passenger_count").tip_amount.mean().compute()
#       2 result
#
# File ~/.local/lib/python3.10/site-packages/dask/base.py:310, in DaskMethodsMixin.compute(self, **kwargs)
#     286 def compute(self, **kwargs):
#     287     """Compute this dask collection
#     288
#     289     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     308     dask.compute
#     309     """
# --> 310     (result,) = compute(self, traverse=False, **kwargs)
#     311     return result
#
# File ~/.local/lib/python3.10/site-packages/dask/base.py:595, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     592     keys.append(x.__dask_keys__())
#     593     postcomputes.append(x.__dask_postcompute__())
# --> 595 results = schedule(dsk, keys, **kwargs)
#     596 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/.local/lib/python3.10/site-packages/distributed/client.py:3243, in Client.get(self, dsk, keys, workers, allow_other_workers, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    3241         should_rejoin = False
#    3242 try:
# -> 3243     results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    3244 finally:
#    3245     for f in futures.values():
#
# File ~/.local/lib/python3.10/site-packages/distributed/client.py:2368, in Client.gather(self, futures, errors, direct, asynchronous)
#    2366 except ValueError:
#    2367     local_worker = None
# -> 2368 return self.sync(
#    2369     self._gather,
#    2370     futures,
#    2371     errors=errors,
#    2372     direct=direct,
#    2373     local_worker=local_worker,
#    2374     asynchronous=asynchronous,
#    2375 )
#
# File ~/.local/lib/python3.10/site-packages/distributed/utils.py:351, in SyncMethodMixin.sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     349     return future
#     350 else:
# --> 351     return sync(
#     352         self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     353     )
#
# File ~/.local/lib/python3.10/site-packages/distributed/utils.py:414, in sync(loop, func, callback_timeout, *args, **kwargs)
#     412 else:
#     413     while not e.is_set():
# --> 414         wait(10)
#     416 if error:
#     417     typ, exc, tb = error
#
# File ~/.local/lib/python3.10/site-packages/distributed/utils.py:403, in sync.<locals>.wait(timeout)
#     401 def wait(timeout):
#     402     try:
# --> 403         return e.wait(timeout)
#     404     except KeyboardInterrupt:
#     405         loop.add_callback(cancel)
#
# File ~/anaconda3/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File ~/anaconda3/lib/python3.10/threading.py:324, in Condition.wait(self, timeout)
#     322 else:
#     323     if timeout > 0:
# --> 324         gotit = waiter.acquire(True, timeout)
#     325     else:
#     326         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
